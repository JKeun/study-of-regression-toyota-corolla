# %%
import pandas as pd

df = pd.read_excel("./ToyotaCorolla.xls", sheetname="data")
df.tail()
# Out:
#         Id                                              Model  Price  Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  Color  Automatic    CC  Doors  Cylinders  Gears  Quarterly_Tax  \
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500         69         12      1998  20544    Petrol   86          1   Blue          0  1300      3          4      5             69
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845         72          9      1998  19000    Petrol   86          0   Grey          0  1300      3          4      5             69
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500         71         10      1998  17016    Petrol   86          0   Blue          0  1300      3          4      5             69
# ...

# %%
df_y = df.Price
df_X = df.ix[:, 3:]

# %%
len(df_y)
# Out:
# 1436

# %%
import seaborn as sns
sns.distplot(df_y)

# %%
log_y = np.log(df_y)
sns.distplot(log_y)

# %%
df[df_y > 15000]
# Out:
#       Id                                              Model  Price  Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color   Color  Automatic    CC  Doors  Cylinders  Gears  Quarterly_Tax  \
# 6      7      TOYOTA Corolla 2.0 D4D 90 3DR TERRA 2/3-Doors  16900         27          6      2002  94612    Diesel   90          1    Grey          0  2000      3          4      5            210
# 7      8      TOYOTA Corolla 2.0 D4D 90 3DR TERRA 2/3-Doors  18600         30          3      2002  75889    Diesel   90          1    Grey          0  2000      3          4      5            210
# 8      9        TOYOTA Corolla 1800 T SPORT VVT I 2/3-Doors  21500         27          6      2002  19700    Petrol  192          0     Red          0  1800      3          4      5            100
# 10    11  TOYOTA Corolla 1.8 VVTL-i T-Sport 3-Drs 2/3-Doors  20950         25          8      2002  31461    Petrol  192          0  Silver          0  1800      3          4      6            100
# ...
